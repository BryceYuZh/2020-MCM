# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import matplotlib.mlab as mlab
# 统计方差
df = pd.read_csv('/Users/zhehaoyu/Desktop/MCM/D题/codes/match_indicator.csv')
df = df.sort_values(['teamID', 'matchID'])
df
# Out:
#     matchID      teamID  avg_clustering  total_degree  clique_number  \
# 0         1     Huskies        0.110728           369              8
# 2         2     Huskies        0.137660           180              7
# 4         3     Huskies        0.138964           324              8
# 6         4     Huskies        0.132631           354              9
# 8         5     Huskies        0.138370           382              9
# 10        6     Huskies        0.096407           318              7
# 12        7     Huskies        0.144553           384              8
# 14        8     Huskies        0.136283           295              9
# 16        9     Huskies        0.144408           168              7
# 18       10     Huskies        0.166429           359              7
# 20       11     Huskies        0.153766           183              8
# 22       12     Huskies        0.138634           132              7
# 24       13     Huskies        0.154970           247              7
# ...

# %%
cent = pd.read_csv('/Users/zhehaoyu/Desktop/MCM/D题/codes/match_indicator_individual.csv')
c = cent.groupby('matchID').mean()
# c['centrality'].plot()
cent.describe()
# Out:
#           matchID  clustering  out_degree  centrality  avg_position_x  \
# count  529.000000  529.000000  529.000000  529.000000      523.000000
# mean    19.499055    0.149033    7.260870    1.708414       49.236942
# std     11.003464    0.049696    2.907019    0.585109       16.172847
# min      1.000000    0.000000    0.000000    0.000000        7.000000
# 25%     10.000000    0.116204    5.000000    1.289459       39.373626
# 50%     20.000000    0.145439    8.000000    1.710526       51.095238
# 75%     29.000000    0.180893    9.000000    2.115049       60.309122
# max     38.000000    0.388056   14.000000    3.413825       94.000000
#
#        avg_position_y
# count      523.000000
# mean        50.466547
# std         21.454075
# min          6.960000
# 25%         35.261364
# 50%         49.918919
# 75%         66.857143
# max         95.000000

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
sns.set(style="darkgrid")

# %%
sns.pairplot(huskies);

# %%
passes =  pd.read_csv('/Users/zhehaoyu/Desktop/MCM/D题/codes/pass_data_in_each_game.csv')
pa = passes.describe()
pa = pa[['total', 'success', 'rate']]
passes = passes[['total', 'success', 'rate']]
passes
# Out:
#     total  success      rate
# 0     482      369  0.765560
# 1     276      180  0.652174
# 2     419      324  0.773270
# 3     446      354  0.793722
# 4     469      382  0.814499
# 5     414      318  0.768116
# 6     501      384  0.766467
# 7     424      295  0.695755
# 8     267      168  0.629213
# 9     456      359  0.787281
# 10    285      183  0.642105
# 11    240      132  0.550000
# 12    303      247  0.815182
# 13    412      347  0.842233
# 14    346      271  0.783237
# 15    159       80  0.503145
# 16    406      304  0.748768
# 17    415      312  0.751807
# 18    320      248  0.775000
# 19    324      230  0.709877
# 20    461      366  0.793926
# 21    353      239  0.677054
# 22    343      236  0.688047
# 23    462      320  0.692641
# 24    331      249  0.752266
# 25    355      287  0.808451
# 26    373      283  0.758713
# 27    334      238  0.712575
# 28    325      220  0.676923
# 29    404      312  0.772277
# 30    430      329  0.765116
# ...

# %%
huskies = df[df['teamID'] == 'Huskies']
hu = huskies.describe()

# %%
# macro 第一问
macro = pd.concat([hu,pa],axis=1)
macro.to_csv('macro_indicator_p1.csv',index=True,sep=',')

# %%
macro
# Out:
#          matchID  avg_clustering  total_degree  clique_number  avg_position_x  \
# count  38.000000       38.000000     38.000000      38.000000       38.000000
# mean   19.500000        0.149138    274.605263       7.763158       49.192537
# std    11.113055        0.029977     75.925119       1.076386        3.557456
# min     1.000000        0.096407     80.000000       5.000000       41.892338
# 25%    10.250000        0.130439    236.500000       7.000000       47.171168
# 50%    19.500000        0.141686    290.000000       8.000000       48.765457
# 75%    28.750000        0.165063    327.750000       8.750000       51.068438
# max    38.000000        0.228421    384.000000      10.000000       56.355859
#
#        avg_position_y       total     success       rate
# count       38.000000   38.000000   38.000000  38.000000
# mean        50.461769  369.552632  274.605263   0.731388
# std          3.772694   80.936978   75.925119   0.076760
# ...

# %%
# 导入第三方模块
import pandas as pd
import matplotlib.pyplot as plt

# 设置图形的显示风格
plt.style.use('seaborn-whitegrid')

# 绘图：整体乘客的年龄箱线图
plt.boxplot(x = [huskies.avg_clustering], # 指定绘图数据
            labels = ['Average clustering coefficient'],
            patch_artist=True, # 要求用自定义颜色填充盒形图，默认白色填充
            showmeans=True, # 以点的形式显示均值
            boxprops = {'color':'black','facecolor':'#9999ff'}, # 设置箱体属性，填充色和边框色
            flierprops = {'marker':'o','markerfacecolor':'red','color':'black'}, # 设置异常值属性，点的形状、填充色和边框色
            meanprops = {'marker':'D','markerfacecolor':'indianred'}, # 设置均值点的属性，点的形状、填充色
            medianprops = {'linestyle':'--','color':'orange'}) # 设置中位数线的属性，线的类型和颜色

# # 设置y轴的范围
# plt.ylim(0.08,0.25)
plt.xticks(fontsize=12)
plt.yticks(fontsize=12)

plt.savefig('Average clustering coefficient.png', dpi=600)
# 显示图形
plt.show()

# %%
# 导入第三方模块
import pandas as pd
import matplotlib.pyplot as plt

# 设置图形的显示风格
plt.style.use('seaborn-whitegrid')

# 绘图：整体乘客的年龄箱线图
plt.boxplot(x = [huskies.avg_position_x,huskies.avg_position_y], # 指定绘图数据
            labels = ['$\overline{X}$','$\overline{Y}$'],
            patch_artist=True, # 要求用自定义颜色填充盒形图，默认白色填充
            showmeans=True, # 以点的形式显示均值
            boxprops = {'color':'black','facecolor':'#9999ff'}, # 设置箱体属性，填充色和边框色
            flierprops = {'marker':'o','markerfacecolor':'red','color':'black'}, # 设置异常值属性，点的形状、填充色和边框色
            meanprops = {'marker':'D','markerfacecolor':'indianred'}, # 设置均值点的属性，点的形状、填充色
            medianprops = {'linestyle':'--','color':'orange'}) # 设置中位数线的属性，线的类型和颜色

# # 设置y轴的范围
# plt.ylim(0.08,0.25)
plt.xticks(fontsize=12)
plt.yticks(fontsize=12)
# 去除箱线图的上边框与右边框的刻度标签
#plt.tick_params(top='off', right='off')
# 显示图形

plt.savefig('average_position.png', dpi=600)
plt.show()

# %%
oppo = df[df['teamID'] != 'Huskies']
oppo = oppo.groupby(['teamID']).mean()
oppo.describe()
# Out:
#          matchID  avg_clustering  total_degree  clique_number  avg_position_x  \
# count  19.000000       19.000000     19.000000      19.000000       19.000000
# mean   19.500000        0.163831    335.763158       7.842105       49.817527
# std     4.907477        0.024044    118.627963       0.817391        2.224003
# min    11.000000        0.124288    202.000000       6.500000       45.383799
# 25%    16.500000        0.145213    246.250000       7.250000       48.048392
# 50%    19.000000        0.158116    301.000000       7.500000       50.302611
# 75%    24.750000        0.182003    416.750000       8.500000       51.328839
# max    26.000000        0.214632    646.500000       9.500000       53.498001
#
#        avg_position_y
# count       19.000000
# mean        48.509306
# std          2.335091
# min         43.614408
# 25%         46.889393
# 50%         47.772440
# 75%         50.256197
# max         52.561660

# %%
result['avg_clustering']['mean']
# Out:
# 0.14913823157000275

# %%
result.to_csv('huskies_statistic.csv',index=True,sep=',')

# %%
# 对方传球成功率

# %%
import math

event = pd.read_csv('/Users/zhehaoyu/Desktop/MCM/D题/2020_Problem_D_DATA/fullevents.csv')
ev = event.sort_values(['MatchID','EventSubType','TeamID'])
ev = event[(event['EventType']=='Pass')& (event['TeamID']!='Huskies')] # & math.isnan(event['DestinationPlayerID'])]
ev = ev.sort_values(['MatchID','OriginPlayerID'])

pnumber = ev.groupby(['MatchID','OriginPlayerID']).count()
pass_data = pnumber[['TeamID','DestinationPlayerID']]
pass_data.columns = ['total','success']
#pass_data['rate'] = pass_data['success']/pass_data['total']
pass_data
# Out:
#                         total  success
# MatchID OriginPlayerID
# 1       Opponent1_D1       24       15
#         Opponent1_D2       28       22
#         Opponent1_D3       29       24
#         Opponent1_D4       13        8
#         Opponent1_F1        9        4
#         Opponent1_F2       24       17
#         Opponent1_F3       13        8
#         Opponent1_F4        3        3
#         Opponent1_F5        9        6
#         Opponent1_G1       15       14
#         Opponent1_M1       45       32
#         Opponent1_M2       22       17
#         Opponent1_M3       33       27
# 2       Opponent2_D1       13       11
#         Opponent2_D2       69       56
#         Opponent2_D3       27       26
#         Opponent2_D4       64       53
#         Opponent2_D5       23       16
#         Opponent2_F1       25       20
#         Opponent2_F2       28       21
#         Opponent2_F3       24       17
#         Opponent2_G1       26       21
# ...

# %%
pass_data = pass_data.groupby('MatchID').sum()
pass_data['rate'] = pass_data['success'] / pass_data['total']
pass_data.describe()
# Out:
#             total     success       rate
# count   38.000000   38.000000  38.000000
# mean   454.526316  341.947368   0.733723
# std    139.825130  143.318762   0.089651
# min    267.000000  172.000000   0.531250
# 25%    367.500000  232.500000   0.664116
# 50%    436.500000  300.000000   0.736170
# 75%    522.500000  425.250000   0.801612
# max    940.000000  877.000000   0.932979

# %%
# 敏感性分析
sen = pd.read_csv('/Users/zhehaoyu/Desktop/MCM/D题/codes/match_indicator.csv')
sen = sen[sen['teamID']=='Huskies']

# %%
sen.describe()
# Out:
#          matchID  avg_clustering  total_degree  clique_number  avg_position_x  \
# count  38.000000       38.000000     38.000000      38.000000       38.000000
# mean   19.500000        0.149138    274.605263       7.763158       49.192537
# std    11.113055        0.029977     75.925119       1.076386        3.557456
# min     1.000000        0.096407     80.000000       5.000000       41.892338
# 25%    10.250000        0.130439    236.500000       7.000000       47.171168
# 50%    19.500000        0.141686    290.000000       8.000000       48.765457
# 75%    28.750000        0.165063    327.750000       8.750000       51.068438
# max    38.000000        0.228421    384.000000      10.000000       56.355859
#
#        avg_position_y
# count       38.000000
# mean        50.461769
# std          3.772694
# min         40.879690
# 25%         49.113640
# 50%         50.738288
# 75%         52.195769
# max         56.565088
