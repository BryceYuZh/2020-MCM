# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import matplotlib.mlab as mlab

# %%
df = pd.read_csv('/Users/zhehaoyu/Desktop/MCM/D题/2020_Problem_D_DATA/passingevents.csv') # 传球
df = df.sort_values(['MatchID', 'OriginPlayerID', 'DestinationPlayerID'])
df
# Out:
#        MatchID      TeamID OriginPlayerID DestinationPlayerID MatchPeriod  \
# 13           1     Huskies     Huskies_D1          Huskies_D2          1H
# 32           1     Huskies     Huskies_D1          Huskies_D2          1H
# 41           1     Huskies     Huskies_D1          Huskies_D2          1H
# 55           1     Huskies     Huskies_D1          Huskies_D2          1H
# 62           1     Huskies     Huskies_D1          Huskies_D2          1H
# 90           1     Huskies     Huskies_D1          Huskies_D2          1H
# 158          1     Huskies     Huskies_D1          Huskies_D2          1H
# 189          1     Huskies     Huskies_D1          Huskies_D2          1H
# 202          1     Huskies     Huskies_D1          Huskies_D2          1H
# 206          1     Huskies     Huskies_D1          Huskies_D2          1H
# 227          1     Huskies     Huskies_D1          Huskies_D2          1H
# 238          1     Huskies     Huskies_D1          Huskies_D2          1H
# 263          1     Huskies     Huskies_D1          Huskies_D2          1H
# 301          1     Huskies     Huskies_D1          Huskies_D2          1H
# 77           1     Huskies     Huskies_D1          Huskies_D3          1H
# 255          1     Huskies     Huskies_D1          Huskies_D3          1H
# 326          1     Huskies     Huskies_D1          Huskies_D3          2H
# 340          1     Huskies     Huskies_D1          Huskies_D3          2H
# 348          1     Huskies     Huskies_D1          Huskies_D3          2H
# 401          1     Huskies     Huskies_D1          Huskies_D3          2H
# 430          1     Huskies     Huskies_D1          Huskies_D3          2H
# 439          1     Huskies     Huskies_D1          Huskies_D3          2H
# 181          1     Huskies     Huskies_D1          Huskies_D4          1H
# 350          1     Huskies     Huskies_D1          Huskies_D5          2H
# 355          1     Huskies     Huskies_D1          Huskies_D5          2H
# 493          1     Huskies     Huskies_D1          Huskies_D5          2H
# 0            1     Huskies     Huskies_D1          Huskies_F1          1H
# 8            1     Huskies     Huskies_D1          Huskies_F1          1H
# 179          1     Huskies     Huskies_D1          Huskies_F1          1H
# 46           1     Huskies     Huskies_D1          Huskies_F2          1H
# ...        ...         ...            ...                 ...         ...
# 23331       38  Opponent14  Opponent14_M5       Opponent14_M4          2H
# 23337       38  Opponent14  Opponent14_M5       Opponent14_M4          2H
# 23393       38  Opponent14  Opponent14_M5       Opponent14_M4          2H
# 23023       38  Opponent14  Opponent14_M5       Opponent14_M6          1H
# 23054       38  Opponent14  Opponent14_M5       Opponent14_M6          1H
# 23227       38  Opponent14  Opponent14_M5       Opponent14_M6          2H
# 23055       38  Opponent14  Opponent14_M6       Opponent14_D1          1H
# 22954       38  Opponent14  Opponent14_M6       Opponent14_D2          1H
# 23020       38  Opponent14  Opponent14_M6       Opponent14_D2          1H
# 23031       38  Opponent14  Opponent14_M6       Opponent14_D2          1H
# 23118       38  Opponent14  Opponent14_M6       Opponent14_D2          1H
# 23118  2750.713883  Simple pass             88              6
# 23346  2060.026316  Simple pass             70              9
# 23007  1812.170033  Simple pass             35             33
# 23125  2819.213779  Simple pass             43             12
# 23313  1786.246470  Simple pass             45             30
# 23127  2821.041235  Simple pass             50              8
# 23010  1865.817153  Simple pass             36              3
# 22965  1393.343975  Simple pass             78             10
# 23045  2116.647461  Simple pass             66             24
# 23081  2547.683746  Simple pass             57             17
# 23254  1035.606660  Simple pass             64             14
# 23261  1166.633857  Simple pass             44             10
# 23216   768.905247  Simple pass             46             28
# 23024  2043.556542  Simple pass             61             24
# 23353  2091.805192  Simple pass             76             10
# 23076  2511.786430  Simple pass             50             11
# 23120  2756.356649  Simple pass             76              9
# 23199   570.613064  Simple pass             75             32
# 23228   825.666780  Simple pass             41             23
# 23340  2020.555273  Simple pass             65             27
#
#        EventDestination_x  EventDestination_y
# 13                   22.0                62.0
# 32                   24.0                55.0
# 41                   29.0                53.0
# 55                   33.0                56.0
# 62                   43.0                46.0
# 90                   39.0                58.0
# 158                  28.0                51.0
# 189                  31.0                47.0
# 202                  33.0                54.0
# 206                  35.0                57.0
# 227                  30.0                56.0
# 238                  36.0                49.0
# 263                  19.0                73.0
# 301                  30.0                50.0
# 77                   22.0                37.0
# 255                  31.0                13.0
# 326                  35.0                43.0
# 340                  22.0                24.0
# 348                  47.0                41.0
# 401                  36.0                35.0
# 430                  28.0                30.0
# 439                   5.0                 9.0
# 181                  98.0                 3.0
# 350                  58.0                97.0
# 355                  24.0                95.0
# 493                  39.0                89.0
# 0                    59.0                95.0
# 8                    52.0                97.0
# 179                  68.0                97.0
# 46                   59.0                67.0
# ...                   ...                 ...
# 23331                35.0                51.0
# 23337                39.0                12.0
# 23393                60.0                21.0
# 23023                61.0                24.0
# 23054                48.0                 5.0
# 23227                41.0                23.0
# 23055                53.0                71.0
# 22954                55.0                13.0
# 23020                29.0                12.0
# 23031                58.0                12.0
# 23118                76.0                12.0
# 23346                61.0                 3.0
# 23007                26.0                34.0
# 23125                47.0                25.0
# 23313                28.0                48.0
# 23127                62.0                10.0
# 23010                 8.0                32.0
# 22965                71.0                31.0
# 23045                54.0                54.0
# 23081                43.0                27.0
# 23254                69.0                 4.0
# 23261                46.0                26.0
# 23216                38.0                47.0
# 23024                74.0                65.0
# 23353                75.0                 2.0
# 23076                55.0                15.0
# 23120                64.0                30.0
# 23199                69.0                32.0
# 23228                39.0                23.0
# 23340                67.0                39.0
#
# [23429 rows x 11 columns]

# %%
#计算每个边权值
cnt = df.groupby(['MatchID', 'OriginPlayerID', 'DestinationPlayerID']).count()
cnt = cnt['TeamID']
cnt
# Out:
# MatchID  OriginPlayerID  DestinationPlayerID
# 1        Huskies_D1      Huskies_D2             14
#                          Huskies_D3              8
#                          Huskies_D4              1
#                          Huskies_D5              3
#                          Huskies_F1              3
#                          Huskies_F2              3
#                          Huskies_F3              1
#                          Huskies_G1              2
#                          Huskies_M1             11
#                          Huskies_M2              1
#                          Huskies_M3              4
#                          Huskies_M4              1
#          Huskies_D2      Huskies_D1             11
#                          Huskies_D3             18
#                          Huskies_F1              1
#                          Huskies_F2              3
#                          Huskies_G1              1
#                          Huskies_M1              1
#                          Huskies_M3              1
#          Huskies_D3      Huskies_D1              6
#                          Huskies_D2              6
#                          Huskies_D4              9
#                          Huskies_F1              1
#                          Huskies_F2              2
#                          Huskies_F3              1
#                          Huskies_G1              6
#                          Huskies_M1              4
#                          Huskies_M2              5
#                          Huskies_M3              6
#                          Huskies_M4              1
#                                                 ..
# 38       Opponent14_M4   Opponent14_D1           2
#                          Opponent14_D2           7
#                          Opponent14_D4           5
#                          Opponent14_D5           1
#                          Opponent14_D6           3
#                          Opponent14_F1           7
#                          Opponent14_G2           1
#                          Opponent14_M1           4
#                          Opponent14_M2           1
#                          Opponent14_M3           4
#                          Opponent14_M5           3
#                          Opponent14_M6           4
#          Opponent14_M5   Opponent14_D1           6
#                          Opponent14_D2           3
#                          Opponent14_D4           1
#                          Opponent14_D6           7
#                          Opponent14_F1           5
#                          Opponent14_M1           9
#                          Opponent14_M3           4
#                          Opponent14_M4           5
#                          Opponent14_M6           3
#          Opponent14_M6   Opponent14_D1           1
#                          Opponent14_D2           5
#                          Opponent14_D4           3
#                          Opponent14_F1           1
#                          Opponent14_G2           1
#                          Opponent14_M1           5
#                          Opponent14_M3           1
#                          Opponent14_M4           2
#                          Opponent14_M5           5
# Name: TeamID, Length: 7668, dtype: int64

# %%
# 计算每个球员位置
location = df.groupby(['MatchID', 'OriginPlayerID']).mean()
location = location[['EventOrigin_x','EventOrigin_y']]
location.to_csv('location.csv',index=True,sep=',')

# %%
cnt.to_csv('weight.csv',index=True,sep=',')
# Out:
# /Users/zhehaoyu/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:1: FutureWarning: The signature of `Series.to_csv` was aligned to that of `DataFrame.to_csv`, and argument 'header' will change its default value from False to True: please pass an explicit value to suppress this warning.
#   """Entry point for launching an IPython kernel.

# %%
import math

event = pd.read_csv('/Users/zhehaoyu/Desktop/MCM/D题/2020_Problem_D_DATA/fullevents.csv')
ev = event.sort_values(['MatchID','EventSubType','TeamID'])
ev = event[(event['EventType']=='Pass')& (event['TeamID']=='Huskies')] # & math.isnan(event['DestinationPlayerID'])]
ev = ev.sort_values(['MatchID','OriginPlayerID'])
# fault = ev[ev['DestinationPlayerID'].isnull()]
# fgroup = fault.groupby(['MatchID','OriginPlayerID']).count()
# fnumber = fgroup['TeamID']
# fnumber
pnumber = ev.groupby(['MatchID','OriginPlayerID']).count()
pass_data = pnumber[['TeamID','DestinationPlayerID']]
pass_data.columns = ['total','success']
pass_data['rate'] = pass_data['success']/pass_data['total']
pass_data.to_csv('pass_success_rate.csv',index=True,sep=',')
# Out:
# /Users/zhehaoyu/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:14: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy

# %%
shot_num = event[event['EventType']=='Shot']
shot_cnt = shot_num.groupby(['MatchID', 'TeamID', 'OriginPlayerID']).count()['MatchPeriod']
shot_cnt.to_csv('shot_number.csv',index=True,sep=',')
# Out:
# /Users/zhehaoyu/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:3: FutureWarning: The signature of `Series.to_csv` was aligned to that of `DataFrame.to_csv`, and argument 'header' will change its default value from False to True: please pass an explicit value to suppress this warning.
#   This is separate from the ipykernel package so we can avoid doing imports until
