# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import matplotlib.mlab as mlab

# %%
df = pd.read_csv('/Users/zhehaoyu/Desktop/MCM/D题/2020_Problem_D_DATA/passingevents.csv')

# %%
match1 = df[(df['MatchID']==1)&(df['TeamID']=='Huskies')]
match2 = df[(df['MatchID']==2)&(df['TeamID']=='Huskies')]
match3 = df[(df['MatchID']==3)&(df['TeamID']=='Huskies')]

# %%
pass1 = match1[['EventOrigin_x','EventOrigin_y','EventDestination_x','EventDestination_y']]
# Out:
#      EventOrigin_x  EventOrigin_y  EventDestination_x  EventDestination_y
# 0               34             97                59.0                95.0
# 1               53             89                69.0                91.0
# 4               42             55                36.0                54.0
# 8               34             91                52.0                97.0
# 11              14             65                11.0                50.0
# 12              11             50                 5.0                45.0
# 13              17             92                22.0                62.0
# 14              22             62                19.0                24.0
# 15              19             24                 8.0                45.0
# 16               8             45                19.0                13.0
# 17              19             13                12.0                38.0
# 18              48             50                55.0                24.0
# ...

# %%
zoom =[]
for i,row in pass1.iterrows():
    if row['EventOrigin_x'] >= 0 and row['EventOrigin_x'] <= 20:
        zoom.append(1)
    if row['EventOrigin_x'] > 20 and row['EventOrigin_x'] <= 40:
        zoom.append(2)
    if row['EventOrigin_x'] > 40 and row['EventOrigin_x'] <= 60:
        zoom.append(3)
    if row['EventOrigin_x'] > 60 and row['EventOrigin_x'] <= 80:
        zoom.append(4)
    if row['EventOrigin_x'] > 80 and row['EventOrigin_x'] <= 100:
        zoom.append(5)
# Out:
# [2,
#  3,
#  3,
#  2,
#  1,
#  1,
#  1,
#  2,
#  1,
#  1,
#  1,
#  3,
#  3,
#  3,
#  2,
#  1,
#  1,
#  2,
#  3,
#  3,
#  3,
#  1,
#  2,
#  2,
#  2,
#  2,
#  2,
#  2,
#  2,
#  2,
#  2,
#  2,
#  2,
#  2,
#  3,
#  2,
#  2,
#  2,
#  2,
#  2,
#  2,
#  2,
#  2,
#  3,
#  3,
#  2,
#  3,
#  2,
#  1,
#  3,
#  3,
#  3,
#  3,
#  3,
#  3,
#  2,
#  2,
#  3,
#  2,
#  2,
#  3,
#  2,
#  2,
#  3,
#  5,
#  5,
#  2,
#  2,
#  2,
#  1,
#  2,
#  3,
#  2,
#  3,
#  2,
#  2,
#  2,
#  1,
#  1,
#  2,
#  2,
#  2,
#  4,
#  3,
#  4,
#  4,
#  4,
#  4,
#  4,
#  4,
#  4,
#  4,
#  2,
#  1,
#  2,
#  2,
#  2,
#  2,
#  1,
#  3,
#  3,
#  2,
#  2,
#  2,
#  3,
#  3,
#  4,
#  3,
#  3,
#  4,
#  3,
#  3,
#  4,
#  3,
#  3,
#  3,
#  4,
#  3,
#  3,
#  4,
#  3,
#  3,
#  3,
#  4,
#  5,
#  3,
#  3,
#  3,
#  1,
#  1,
#  3,
#  3,
#  2,
#  2,
#  3,
#  4,
#  3,
#  3,
#  2,
#  3,
#  3,
#  3,
#  4,
#  4,
#  1,
#  2,
#  2,
#  2,
#  3,
#  3,
#  2,
#  3,
#  3,
#  3,
#  3,
#  2,
#  3,
#  3,
#  3,
#  3,
#  1,
#  1,
#  2,
#  2,
#  2,
#  2,
# ...

# %%
pass1['room'] = zoom
# Out:
# /Users/zhehaoyu/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   """Entry point for launching an IPython kernel.

# %%
pass1['huskies_dx'] = pass1['EventDestination_x'] - pass1['EventOrigin_x']
pass1['huskies_dy'] = abs(pass1['EventDestination_y'] - pass1['EventOrigin_y'])
pass1['huskies_k'] = pass1['huskies_dy'] / pass1['huskies_dx']
result = pass1[['room','huskies_k']]
result.to_csv('short_time_k vs. room.csv',index=True,sep=',')
# Out:
# /Users/zhehaoyu/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   """Entry point for launching an IPython kernel.
# /Users/zhehaoyu/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#
# /Users/zhehaoyu/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# ...

# %%
re
