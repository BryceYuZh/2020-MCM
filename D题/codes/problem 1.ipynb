# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import matplotlib.mlab as mlab

# %%
df = pd.read_csv('/Users/zhehaoyu/Desktop/MCM/D题/2020_Problem_D_DATA/passingevents.csv')

# %%
match1 = df[(df['MatchID']==1)&(df['TeamID']=='Huskies')]
match2 = df[(df['MatchID']==2)&(df['TeamID']=='Huskies')]
match3 = df[(df['MatchID']==3)&(df['TeamID']=='Huskies')]

# %%
pass1 = match1[['EventOrigin_x','EventOrigin_y','EventDestination_x','EventDestination_y']]
pass2 = match2[['EventOrigin_x','EventOrigin_y','EventDestination_x','EventDestination_y']]
pass3 = match3[['EventOrigin_x','EventOrigin_y','EventDestination_x','EventDestination_y']]

# %%
zoom =[]
for i,row in pass1.iterrows():
    if row['EventOrigin_x'] >= 0 and row['EventOrigin_x'] <= 20:
        zoom.append(1)
    if row['EventOrigin_x'] > 20 and row['EventOrigin_x'] <= 40:
        zoom.append(2)
    if row['EventOrigin_x'] > 40 and row['EventOrigin_x'] <= 60:
        zoom.append(3)
    if row['EventOrigin_x'] > 60 and row['EventOrigin_x'] <= 80:
        zoom.append(4)
    if row['EventOrigin_x'] > 80 and row['EventOrigin_x'] <= 100:
        zoom.append(5)

pass1['room'] = zoom
pass1['huskies_dx'] = pass1['EventDestination_x'] - pass1['EventOrigin_x']
pass1['huskies_dy'] = abs(pass1['EventDestination_y'] - pass1['EventOrigin_y'])
pass1['huskies_k'] = pass1['huskies_dy'] / pass1['huskies_dx']
result = pass1[['room','huskies_k']]
result
result.to_csv('short_time_k vs. room.csv',index=True,sep=',')
# Out:
# /Users/zhehaoyu/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:14: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#
# /Users/zhehaoyu/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:15: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   from ipykernel import kernelapp as app
# /Users/zhehaoyu/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:16: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   app.launch_new_instance()
# /Users/zhehaoyu/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:17: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#      room  huskies_k
# 0       2   0.080000
# 1       3   0.125000
# 4       3  -0.166667
# 8       2   0.333333
# 11      1  -5.000000
# 12      1  -0.833333
# 13      1   6.000000
# 14      2 -12.666667
# 15      1  -1.909091
# 16      1   2.909091
# 17      1  -3.571429
# 18      3   3.714286
# 19      3   3.800000
# 20      3  -0.592593
# 21      2  -2.722222
# 22      1   0.644444
# 24      1   0.750000
# 25      2  -2.200000
# 26      3        inf
# 27      3  -6.500000
# 28      3  14.000000
# 31      1   2.294118
# 32      2 -39.000000
# 33      2        inf
# 34      2   0.000000
# 35      2        inf
# 36      2  -1.222222
# 37      2   8.800000
# 38      2  -5.000000
# 39      2   1.833333
# ..    ...        ...
# 480     4  -0.307692
# 481     3   6.166667
# 486     5  -0.812500
# 493     2   3.416667
# 494     2  -1.571429
# 498     2   1.125000
# 511     4   0.466667
# 512     5  -0.125000
# 513     3  -4.200000
# 514     3  -1.857143
# 534     1   1.312500
# 536     4   2.500000
# 537     4   0.380952
# 542     1  -3.615385
# 543     1   1.122449
# 544     3  -0.642857
# 545     3  -1.833333
# 546     2   0.100000
# 547     3  -1.300000
# 548     2   5.666667
# 549     3  -2.454545
# 551     3   3.500000
# 552     5  -0.400000
# 553     4   4.666667
# 558     2   1.625000
# 559     2   5.777778
# 561     4   0.458333
# 562     5  -0.222222
# 563     4   1.000000
# 564     5   9.000000
#
# [369 rows x 2 columns]

# %%
zoom2 =[]
for i,row in pass2.iterrows():
    if row['EventOrigin_x'] >= 0 and row['EventOrigin_x'] <= 20:
        zoom2.append(1)
    if row['EventOrigin_x'] > 20 and row['EventOrigin_x'] <= 40:
        zoom2.append(2)
    if row['EventOrigin_x'] > 40 and row['EventOrigin_x'] <= 60:
        zoom2.append(3)
    if row['EventOrigin_x'] > 60 and row['EventOrigin_x'] <= 80:
        zoom2.append(4)
    if row['EventOrigin_x'] > 80 and row['EventOrigin_x'] <= 100:
        zoom2.append(5)

pass2['room'] = zoom2
pass2['huskies_dx'] = pass2['EventDestination_x'] - pass2['EventOrigin_x']
pass2['huskies_dy'] = abs(pass2['EventDestination_y'] - pass2['EventOrigin_y'])
pass2['huskies_k'] = pass2['huskies_dy'] / pass2['huskies_dx']
result2 = pass2[['room','huskies_k']]
result2.to_csv('short_time_k vs. room2.csv',index=True,sep=',')
# Out:
# /Users/zhehaoyu/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:14: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#
# /Users/zhehaoyu/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:15: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   from ipykernel import kernelapp as app
# /Users/zhehaoyu/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:16: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   app.launch_new_instance()
# /Users/zhehaoyu/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:17: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy

# %%
zoom3 =[]
for i,row in pass3.iterrows():
    if row['EventOrigin_x'] >= 0 and row['EventOrigin_x'] <= 20:
        zoom3.append(1)
    if row['EventOrigin_x'] > 20 and row['EventOrigin_x'] <= 40:
        zoom3.append(2)
    if row['EventOrigin_x'] > 40 and row['EventOrigin_x'] <= 60:
        zoom3.append(3)
    if row['EventOrigin_x'] > 60 and row['EventOrigin_x'] <= 80:
        zoom3.append(4)
    if row['EventOrigin_x'] > 80 and row['EventOrigin_x'] <= 100:
        zoom3.append(5)

pass3['room'] = zoom3
pass3['huskies_dx'] = pass3['EventDestination_x'] - pass3['EventOrigin_x']
pass3['huskies_dy'] = abs(pass3['EventDestination_y'] - pass3['EventOrigin_y'])
pass3['huskies_k'] = pass3['huskies_dy'] / pass3['huskies_dx']
result3 = pass3[['room','huskies_k']]
result3.to_csv('short_time_k vs. room3.csv',index=True,sep=',')
# Out:
# /Users/zhehaoyu/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:14: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#
# /Users/zhehaoyu/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:15: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   from ipykernel import kernelapp as app
# /Users/zhehaoyu/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:16: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   app.launch_new_instance()
# /Users/zhehaoyu/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:17: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy

# %%
clust = pd.read_csv('/Users/zhehaoyu/Desktop/MCM/D题/codes/match_indicator_individual.csv')

# %%
clust = clust[clust['matchID']==1]
clust = clust.sort_values(['clustering'],ascending=False)
clust = clust[['PlayerID','clustering']]
clust
# Out:
#       PlayerID  clustering
# 1   Huskies_D2    0.157435
# 4   Huskies_D5    0.147338
# 11  Huskies_M3    0.140795
# 0   Huskies_D1    0.134336
# 2   Huskies_D3    0.119641
# 6   Huskies_F2    0.110540
# 9   Huskies_M1    0.108802
# 8   Huskies_G1    0.107002
# 10  Huskies_M2    0.103523
# 3   Huskies_D4    0.103431
# 12  Huskies_M4    0.088409
# 7   Huskies_F3    0.077122
# 5   Huskies_F1    0.076168
# 13  Huskies_M5    0.075647
